# %%
# %%bash
# python3 -m venv venv
# # Use the venv's python to install so the same interpreter runs the script later
# venv/bin/python -m pip install --upgrade pip
# venv/bin/python -m pip install -r measure_requirements.txt

# %%
# %%bash
# # Ensure mediapipe and opencv are installed in the venv (no-op if already present)
# venv/bin/python -m pip install mediapipe opencv-python --quiet || true
# # Run the measurement script with the venv's python and force a file backend to avoid inline backend errors
# MPLBACKEND=agg venv/bin/python measure_from_image.py imgs/test.jpg
# Out:
# MESA: error: ZINK: failed to choose pdev
# libEGL warning: egl: failed to create dri2 screen
# libEGL warning: egl: failed to create dri2 screen
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763291673.204013    7561 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763291673.204013    7561 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1763291673.255647    7682 gl_context.cc:357] GL version: 3.0 (OpenGL ES 3.0 Mesa 24.0.9-0ubuntu0.3), renderer: D3D12 (Intel(R) UHD Graphics)
# I0000 00:00:1763291673.255647    7682 gl_context.cc:357] GL version: 3.0 (OpenGL ES 3.0 Mesa 24.0.9-0ubuntu0.3), renderer: D3D12 (Intel(R) UHD Graphics)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# ...
